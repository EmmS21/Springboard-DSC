# %% [markdown]
# ### Explanatory
# - The idea behind this is to create visualisations to compare the distributions of random samples we extract from the gaussian kde and compare that to the actual distribution and its probabilities

# %%
import pandas as pd
import numpy as np
import glob
from scipy import stats
import matplotlib.pyplot as plt
pickle_files = glob.glob("/Users/emmanuels/Documents/AttributionData/Data/Probabilities/**/*.pck",recursive=True)

# %%
pickle_files
# Out:
# ['/Users/emmanuels/Documents/AttributionData/Data/Probabilities/opportunitytocompleteprobabs.pck',
#  '/Users/emmanuels/Documents/AttributionData/Data/Probabilities/Sessiontoleadprobabs.pck',
#  '/Users/emmanuels/Documents/AttributionData/Data/Probabilities/leadtoopportunityprobabs.pck',
#  '/Users/emmanuels/Documents/AttributionData/Data/Probabilities/untitled folder 2/opportunitytocompleteprobabs.pck',
#  '/Users/emmanuels/Documents/AttributionData/Data/Probabilities/untitled folder 2/Sessiontoleadprobabs.pck',
#  '/Users/emmanuels/Documents/AttributionData/Data/Probabilities/untitled folder 2/leadtoopportunityprobabs.pck',
#  '/Users/emmanuels/Documents/AttributionData/Data/Probabilities/untitled folder 3/opportunitytocompleteprobabs.pck',
#  '/Users/emmanuels/Documents/AttributionData/Data/Probabilities/untitled folder 3/Sessiontoleadprobabs.pck',
#  '/Users/emmanuels/Documents/AttributionData/Data/Probabilities/untitled folder 3/leadtoopportunityprobabs.pck',
#  '/Users/emmanuels/Documents/AttributionData/Data/Probabilities/untitled folder 3/opportunitytocomplete+sampleprobabsprobabs.pck',
#  '/Users/emmanuels/Documents/AttributionData/Data/Probabilities/untitled folder 3/leadtoopportunity+sampleprobabsprobabs.pck',
#  '/Users/emmanuels/Documents/AttributionData/Data/Probabilities/untitled folder 3/Sessiontolead+sampleprobabsprobabs.pck',
#  '/Users/emmanuels/Documents/AttributionData/Data/Probabilities/new/opportunitytocompleteprobabs.pck',
#  '/Users/emmanuels/Documents/AttributionData/Data/Probabilities/new/Sessiontoleadprobabs.pck',
#  '/Users/emmanuels/Documents/AttributionData/Data/Probabilities/new/leadtoopportunityprobabs.pck']

# %%
#visualisation function
def visualise_kde(sample):
    data = pd.read_pickle(sample)
    lab = sample.split('/')[7][:-4]
    x = np.linspace(start=stats.norm.ppf(0.1),
                    stop=stats.norm.ppf(0.99),num=100)
    fig,ax = plt.subplots()
    ax.plot(x, data.pdf(x), linestyle='dashed', c='red', lw=2,
        alpha=0.8)
    ax.set_title(lab+' KDE visualisation',fontsize=15)
    #sample plot
    ax_two = ax.twinx()
    #take a sample of 10000 as a dataframe
    sample_two = pd.DataFrame(data.resample(10000))
    sample_two = sample_two.transpose()
    sample_two.columns = ['samples']
    ax_two = plt.hist(sample_two['samples'],bins=10)
    return ax,ax_two

# %%
#create visualisations to compare sample to actual distribution
for i in pickle_files:
    visualise_kde(i)
